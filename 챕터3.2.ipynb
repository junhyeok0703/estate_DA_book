# %% [markdown]
# ### 공급량이 부동산 가격에 미치는 영향
# - 수요 - 시장에서 특정 재화를 사람들이 원하는 정도
# - 공급 - 시장에 제공되는 재화의 양 (공급물량)
# - 수요 < 공급 재화의 가격은 하락
# - 공급량 역시 데이터가 없어서 수요를 전세가격지수나 매매가격지수로 봤던 것처럼 정의를 해야함.
# - 공급량예측을 위한 데이터는 -> 주택건설 인허가 데이터, 미분양 데이터를 이용해보자
#
# - 주택건설 인허가 -> 주택건설 사업 계획을 승인받은 수, 2~3년 후에 해당지역에 공급주택물량을 가늠할수있음 -> 해당 지역의 공급량의 큰 흐름을 파악하기에는 충분
#     - 어떤 지역이 2015년에 인허가량이 증가했다면 2017년도정도에 공급량이 증가할것이다라고 생각하고 부동산 가격에 부정적인 영향을 끼칠것이다라고 예상.
# - 미분양 데이터 -> 분양이 안되지않고 한마디로 팔리지않고 남은 주택 데이터
#     - 어떤 지역의 미분양 주택이 증가하면 해당 지역에 주택들이 집주인을 찾지 못해서 수요 < 공급 인 상태이다.
# - 인허가보다 미분양 데이터가 부동산가격의 강력하게 하락을 나타내는 신호이다.
# - 공급이 수요를 넘어선 결과로 나타나는것이 미분양의 증가이다. (중요)
# - 반면 인허가의 증가는 공급이 증가할 가능성이 높지만 공급이 수요보다 높을거라고는 보장이 없다.
# - 따라서 미분양 데이터가 증가하면 부정적인 신호고 확실하게 공급이 많은 상태이다. -> 주택하락가능성이 높다

# %% [markdown]
# ### 인허가 데이터
# - 2010년의 서울 지역의 주택 인허가 실적과 매매가격지수의 움직임을 보자.
# 2~3년뒤에 준공이 끝나므로 2~3년뒤에 가격에 영향을 미칠것이다.
# 그렇게 시간을 2년후로 맞춰놓고 인허가랑 매매가격지수를 보게 되면 초반에 증가하면 매매지수가 하락을 찍게 되지만
# 공급이 감소하자 점점 가격이 계속 상승하는 모습이 보인다. 인허가의 상승이 또있었지만 매매가가 꺽이지않는모습을 보게 되면 인허가로 부동산 가격을 예측하는 것은 한계가 존재한다는것을 알수있게 된다.
# 반면 인허가를 잘 예측한 경우도 존재한다.
# 인허가가 급증했다면 조심하는 것은 나쁠게 없다고 생각된다.

# %% [markdown]
# ### 미분양데이터
# 미분양이 높아질수록 매매가격이 떨어지는것이 훨씬 더 정확하게 보인다.
# 지속성이 강해질수록 가격의 하락이 더 강하게 반대로 움직이게 된다. 일시적일경우는 큰 영향을 끼치지 못한다

# %% [markdown]
# 인허가와 미분양은 단순히 증가 감소만 봐서는 안되고 절대값이 어느정도 수준이고 얼마나 지속하는지가 중요하다.
# 수요 전략을 보충하는데 사용해보자.
# 수요 전략에 의해 선택된 지역들의 인허가나 미분양을 살펴보고 공급 측면에서 투자하기 적합한 지역인지 살펴보고 확실을 다져보자.
# 1. 부산 -> 수요 전략에서 추출된 지역중 하나다. 미분양과 같이 보면 지지부진한 움직임 보인다. 미분양이 쌓였고 급등하다가 미분양의 꼭대기부터 매매가가 지지부진한 모습을 보이게 되어
# -> 결국엔 미분양이 다시 안정화되면 괜찮을지도?... 지지부진하지만 떨어지는 모습은 아니다. 예전만큼 매매가가 크게 변하지않을수도있다.
# 2. 서울 -> 미분양데이터가 하락하면서 매매가와 전세가가 우상향 추세이다. 이로보이는건 일시적 상승이 아닌 서울 부동산의 상승을 확신하는 근거이다.

# %%
import pandas as pd


permission_path = r'/Users/parkjunhyeok/Desktop/부동산데이터분석/주택건설인허가실적.xlsx'
pd.read_excel(permission_path)
# Out:
#       * 통계표명 :              주택건설인허가실적 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     * 수록기간 :  2007년 01월 ~ 2018년 08월        NaN        NaN        NaN
# 1     * 조회기간 :  2007년 01월 ~ 2018년 08월        NaN        NaN        NaN
# 2       * 출처 :                  국토교통부        NaN        NaN        NaN
# 3   * 자료다운일자 :    2018.11.02 21:05:13        NaN        NaN        NaN
# 4       * 단위 :                      건        NaN        NaN        NaN
# 5          NaN                    NaN        NaN        NaN        NaN
# 6          NaN                    NaN        NaN        NaN        NaN
# 7          NaN                    NaN        NaN        NaN        NaN
# 8          NaN                    NaN        NaN        NaN        NaN
# 9          지 역              2007년 01월  2007년 02월  2007년 03월  2007년 04월
# 10          전국                  12038      17751      20038      19186
# 11          서울                   1530        794       1888       1963
# 12          부산                    455       1099       2121        364
# 13          대구                    818       2731       1047        514
# 14          인천                     69        116        930       3337
# 15          광주                   1022       1178       1347        226
# 16          대전                     55         34         65         81
# 17          울산                    183       1173        685       2281
# 18          세종                      -          -          -          -
# 19          경기                   2647       2870       3188       3987
# 20          강원                    452        190        389       1154
# 21          충북                    188        305        694        464
# 22          충남                   1004       1306       1890        701
# 23          전북                    888        602        663        474
# 24          전남                    206        494        391       1219
# 25          경북                    698       2244       2314       1224
# 26          경남                   1691       2515       2321       1049
# 27          제주                    132        100        105        148
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 131  \
# 0         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 5         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 6         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 7         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 8         NaN        NaN        NaN        NaN        NaN  ...          NaN
# 9   2007년 05월  2007년 06월  2007년 07월  2007년 08월  2007년 09월  ...    2017년 11월
# 10      30593      30830      45848      48461      55745  ...        50292
# 11       1866       1893       7338      11719      13182  ...         7797
# 12        897        235       9678       6688       5079  ...         2645
# 13        575        887        439        754       2305  ...          918
# 14        211       5349       1207       1401       4464  ...         1983
# 15       2071        139       1559        478       1117  ...          145
# 16        511        427         54         51         46  ...           85
# 17        244       1787       4248       1506       4007  ...         1596
# 18          -          -          -          -          -  ...         2423
# 19      13168       7071      10964      15170      15969  ...        20301
# 20        513       1535        483       1222        913  ...         1282
# 21        680       2549        803       2075       1202  ...         4391
# 22       3087       1600       1856       1407        991  ...         1134
# 23        311        927        315        402        240  ...          676
# 24        353       3090       1698        757       1762  ...         2115
# 25        850       1184       3482       1200       2711  ...         1217
# 26       5178       1714       1429       3220       1714  ...         1048
# 27         78        443        295        411         43  ...          536
#
#    Unnamed: 132 Unnamed: 133 Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9     2017년 12월    2018년 01월    2018년 02월    2018년 03월    2018년 04월
# 10       100883        37696        43396        38479        46737
# 11        16051         5694         3504         4361         5291
# 12         1765         3052         1959         3046         1679
# 13         4718          947         9438          944         1213
# 14         5702         5079         1560         3351         3608
# 15         1656          227         1289          112          471
# 16         3907          190          312         1067          227
# 17         3186          145          212          226         1931
# 18         3154           50          223           54           68
# 19        34387         9129        16529        11707        15294
# 20         2336         3312          795         1754         3282
# 21         3702         3259         2181         1391         2141
# 22         3930         2136         1678         1960         2207
# 23         1999         1060          404          327          520
# 24         3134          378         1501         1063         2432
# 25         2800         1196          569         3065         3468
# 26         7843         1113          849         3422         1898
# 27          613          729          393          629         1007
#
#    Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140
# 0           NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN
# 9     2018년 05월    2018년 06월    2018년 07월    2018년 08월
# 10        38919        44278        58295        38299
# 11         5490         3625         6305         4296
# 12         2391         5269        10817         1637
# 13         1252         3536          829         3075
# 14         1132          396         1850         7872
# 15          953         2363         5436          246
# 16          278          241         2372          309
# 17          676         1571          197          382
# 18           68           37           81           42
# 19         9278        12027        13733         9452
# 20         2784         3448         2244         1364
# 21         1770         5055         2522         1514
# 22          728         1287         1767         1465
# 23         1906          701         1567          506
# 24         1651         1198         2471         1066
# 25         3894         2182         3607         1448
# 26         3558          848         1949         3109
# 27         1110          494          548          516
#
# [28 rows x 141 columns]

# %%
permission_raw = pd.read_excel(permission_path, skiprows=10, index_col=0)

# %%
transposed_permission = permission_raw.T

# %%
transposed_permission.head()
# Out:
# 지 역           전국    서울    부산    대구    인천    광주   대전    울산 세종     경기    강원  \
# 2007년 01월  12038  1530   455   818    69  1022   55   183  -   2647   452
# 2007년 02월  17751   794  1099  2731   116  1178   34  1173  -   2870   190
# 2007년 03월  20038  1888  2121  1047   930  1347   65   685  -   3188   389
# 2007년 04월  19186  1963   364   514  3337   226   81  2281  -   3987  1154
# 2007년 05월  30593  1866   897   575   211  2071  511   244  -  13168   513
#
# 지 역         충북    충남   전북    전남    경북    경남   제주
# 2007년 01월  188  1004  888   206   698  1691  132
# 2007년 02월  305  1306  602   494  2244  2515  100
# 2007년 03월  694  1890  663   391  2314  2321  105
# 2007년 04월  464   701  474  1219  1224  1049  148
# 2007년 05월  680  3087  311   353   850  5178   78

# %%
new_index = []

for old_date in transposed_permission.index:
    temp_list = old_date.split(' ')
    new_index.append(temp_list[0][:4] + '.' + temp_list[1][:2])

# %%
new_index[:5]
# Out:
# ['2007.01', '2007.02', '2007.03', '2007.04', '2007.05']

# %%
transposed_permission.index = pd.to_datetime(new_index)
transposed_permission.columns.name = None
# Out:
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/2515800301.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   transposed_permission.index = pd.to_datetime(new_index)

# %%
transposed_permission.head()
# Out:
#                전국    서울    부산    대구    인천    광주   대전    울산 세종     경기    강원  \
# 2007-01-01  12038  1530   455   818    69  1022   55   183  -   2647   452
# 2007-02-01  17751   794  1099  2731   116  1178   34  1173  -   2870   190
# 2007-03-01  20038  1888  2121  1047   930  1347   65   685  -   3188   389
# 2007-04-01  19186  1963   364   514  3337   226   81  2281  -   3987  1154
# 2007-05-01  30593  1866   897   575   211  2071  511   244  -  13168   513
#
#              충북    충남   전북    전남    경북    경남   제주
# 2007-01-01  188  1004  888   206   698  1691  132
# 2007-02-01  305  1306  602   494  2244  2515  100
# 2007-03-01  694  1890  663   391  2314  2321  105
# 2007-04-01  464   701  474  1219  1224  1049  148
# 2007-05-01  680  3087  311   353   850  5178   78

# %%
# 함수화
def permission_preprocessing(path):
    permission_raw = pd.read_excel(path, skiprows=10, index_col=0)
    transposed_permission = permission_raw.T
    new_index = []

    for old_date in transposed_permission.index:
        temp_list = old_date.split(' ')
        new_index.append(temp_list[0][:4] + '.' + temp_list[1][:2])
        
    transposed_permission.index = pd.to_datetime(new_index)
    transposed_permission.columns.name = None
    
    return transposed_permission

# %%
unsold_path = r'/Users/parkjunhyeok/Desktop/부동산데이터분석/시·군·구별+미분양현황_2082_128_20181229151931.xlsx'
unsold_raw = pd.read_excel(unsold_path, skiprows=1, index_col=0)
# Out:
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
unsold_raw.head()
# Out:
#    시군구  2007-01  2007-02  2007-03  2007-04  2007-05  2007-07  2007-08  \
# 구분
# 서울   계    697.0    590.0    687.0    685.0    704.0    840.0    730.0
# 부산   계   8680.0   8576.0   8548.0   8074.0   7964.0   9557.0   9925.0
# 대구   계   9467.0   9134.0   9189.0   9009.0  10888.0  12179.0  12075.0
# 인천   계    243.0    312.0    266.0    219.0    362.0    797.0    635.0
# 광주   계   7005.0   6246.0   5905.0   5829.0   7842.0   7186.0   7433.0
#
#     2007-09  2007-10  ...  2018-02  2018-03  2018-04  2018-05  2018-06  \
# 구분                    ...
# 서울    724.0    977.0  ...       48       48       47       47       47
# 부산  10739.0  12012.0  ...     2937     2703     2427     2238     2169
# 대구  11944.0  11879.0  ...      135      153      230      194      506
# 인천    507.0    330.0  ...     1246     1237     1311     1186     1327
# 광주   7294.0   7600.0  ...      431      383      366      338      317
#
#     2018-07  2018-08  2018-09  2018-10  2018-11
# 구분
# 서울       42       39     29.0     28.0       28
# 부산     3266     3129   3111.0   3205.0     3920
# 대구     1345      945    745.0    575.0      429
# 인천     1260     1208   1135.0   1122.0     1394
# 광주      266      240    194.0    194.0       75
#
# [5 rows x 143 columns]

# %%
del unsold_raw['시군구']
transposed_unsold = unsold_raw.T
transposed_unsold.index = pd.to_datetime(transposed_unsold.index)
transposed_unsold.columns.name = None

# %%
def unsold_preprocessing(path):
    unsold_raw = pd.read_excel(path, skiprows=1, index_col=0)
    
    del unsold_raw['시군구']
    transposed_unsold = unsold_raw.T
    transposed_unsold.index = pd.to_datetime(transposed_unsold.index)
    transposed_unsold.columns.name = None
    
    return transposed_unsold

# %%
# [예제 3.30] KBpriceindex_preprocessing 함수 가져오기

import xlwings as xw

def KBpriceindex_preprocessing(path, data_type):
    # path : KB 데이터 엑셀 파일의 디렉토리 (문자열)
    # data_type : ‘매매종합’, ‘매매APT’, ‘매매연립’, ‘매매단독’, ‘전세종합’, ‘전세APT’, ‘전세연립’, ‘전세단독’ 중 하나
    
    wb = xw.Book(path)                
    sheet = wb.sheets[data_type]   
    row_num = sheet.range('A1').end('down').end('down').end('down').row 
    data_range = 'A2:GE' + str(row_num)
    raw_data = sheet[data_range].options(pd.DataFrame, index=False, header=True).value 
    
    bignames = '서울 대구 부산 대전 광주 인천 울산 세종 경기 강원 충북 충남 전북 전남 경북 경남 제주도 6개광역시 5개광역시 수도권 기타지방 구분 전국'
    bigname_list = bignames.split(' ')
    big_col = list(raw_data.columns)
    small_col = list(raw_data.iloc[0])

    for num, gu_data in enumerate(small_col):
        if gu_data == None:
            small_col[num] = big_col[num]

        check = num
        while True:
            if big_col[check] in bigname_list:
                big_col[num] = big_col[check]
                break
            else:
                check = check - 1
                
    big_col[129] = '경기' 
    big_col[130] = '경기'
    small_col[185] = '서귀포'
    
    raw_data.columns = [big_col, small_col]
    new_col_data = raw_data.drop([0,1])
    
    index_list = list(new_col_data['구분']['구분'])

    new_index = []

    for num, raw_index in enumerate(index_list):
        temp = str(raw_index).split('.')
        if int(temp[0]) > 12 :
            if len(temp[0]) == 2:
                new_index.append('19' + temp[0] + '.' + temp[1])
            else:
                new_index.append(temp[0] + '.' + temp[1])
        else:
            new_index.append(new_index[num-1].split('.')[0] + '.' + temp[0])

    new_col_data.set_index(pd.to_datetime(new_index), inplace=True)
    cleaned_data  = new_col_data.drop(('구분', '구분'), axis=1)
    return cleaned_data

# %%
permission_path  = r'/Users/parkjunhyeok/Desktop/부동산데이터분석/주택건설인허가실적.xlsx'
permission = permission_preprocessing(permission_path)
unsold_path = r'/Users/parkjunhyeok/Desktop/부동산데이터분석/시·군·구별+미분양현황_2082_128_20181229151931.xlsx'
unsold = unsold_preprocessing(unsold_path)
kb_path = r'/Users/parkjunhyeok/Desktop/부동산데이터분석/★(월간)KB주택가격동향_시계열(2019.01)12831994601335062.xls'
price_index = KBpriceindex_preprocessing(kb_path, '매매종합')
jun_index   = KBpriceindex_preprocessing(kb_path, '전세종합')
# Out:
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/4173749285.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   transposed_permission.index = pd.to_datetime(new_index)
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/3439630874.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_col_data.set_index(pd.to_datetime(new_index), inplace=True)
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/3439630874.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_col_data.set_index(pd.to_datetime(new_index), inplace=True)

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10,6))
ax = plt.subplot()
ax2 = ax.twinx()

si = '서울'
gu = '서울'

plt.title(si + '-' + gu)
ln1 = ax.plot(price_index[si][gu]['2009-1':], label='매매가')
ln2 = ax2.plot(permission[si]['2009-1':], label='인허가', color='green',marker="o")
lns = ln1 +ln2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='upper left')
    
plt.show()

# %%
permission.index = pd.to_datetime(permission.index)

# %%
permission
# Out:
#                전국    서울     부산    대구    인천    광주    대전    울산  세종     경기    강원  \
# 2007-01-01  12038  1530    455   818    69  1022    55   183   -   2647   452
# 2007-02-01  17751   794   1099  2731   116  1178    34  1173   -   2870   190
# 2007-03-01  20038  1888   2121  1047   930  1347    65   685   -   3188   389
# 2007-04-01  19186  1963    364   514  3337   226    81  2281   -   3987  1154
# 2007-05-01  30593  1866    897   575   211  2071   511   244   -  13168   513
# ...           ...   ...    ...   ...   ...   ...   ...   ...  ..    ...   ...
# 2018-04-01  46737  5291   1679  1213  3608   471   227  1931  68  15294  3282
# 2018-05-01  38919  5490   2391  1252  1132   953   278   676  68   9278  2784
# 2018-06-01  44278  3625   5269  3536   396  2363   241  1571  37  12027  3448
# 2018-07-01  58295  6305  10817   829  1850  5436  2372   197  81  13733  2244
# 2018-08-01  38299  4296   1637  3075  7872   246   309   382  42   9452  1364
#
#               충북    충남    전북    전남    경북    경남    제주
# 2007-01-01   188  1004   888   206   698  1691   132
# 2007-02-01   305  1306   602   494  2244  2515   100
# 2007-03-01   694  1890   663   391  2314  2321   105
# 2007-04-01   464   701   474  1219  1224  1049   148
# 2007-05-01   680  3087   311   353   850  5178    78
# ...          ...   ...   ...   ...   ...   ...   ...
# 2018-04-01  2141  2207   520  2432  3468  1898  1007
# 2018-05-01  1770   728  1906  1651  3894  3558  1110
# 2018-06-01  5055  1287   701  1198  2182   848   494
# 2018-07-01  2522  1767  1567  2471  3607  1949   548
# 2018-08-01  1514  1465   506  1066  1448  3109   516
#
# [140 rows x 18 columns]

# %%
permission.replace('-', pd.NA, inplace=True)  # '-' 값을 NaN으로 변환
permission = permission.fillna(0)  # NaN을 0으로 채우기
# Out:
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/2764010962.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   permission.replace('-', pd.NA, inplace=True)  # '-' 값을 NaN으로 변환
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/2764010962.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   permission = permission.fillna(0)  # NaN을 0으로 채우기

# %%
year_permission = permission.groupby(permission.index.year).sum(numeric_only=True)

# %%
year_permission
# Out:
#           전국      서울     부산     대구     인천     광주     대전     울산     세종      경기  \
# 2007  555792   62842  41254  18174  41571  13088  11180  24507      0  198138
# 2008  371285   48417  13594  22880  33632   3945  14556   5897      0  115531
# 2009  381787   36090   6506   6645  59519   5024   1849   6728      0  159549
# 2010  386542   69190  18331   4724  37477   4487   4034   4904      0  143551
# 2011  549594   88060  37256  12462  35905  16059  19736  13146      0  148191
# 2012  586884   86123  42333  13012  32132  19584   6708   9751  17434  151035
# 2013  440116   77621  29922  18078  18907   8454   5180   5344  17844   96082
# 2014  515251   65249  17210  19079  13583  11056   5073  12502  12447  163057
# 2015  765328  101235  33535  27118  30590  14673   7987  12459  15235  276948
# 2016  726048   74739  36664  23169  22186  22796  13509  16325  12627  244237
# 2017  653441  113131  47159  31378  22689  20326   9953  12747   9332  185582
# 2018  346099   38566  29850  21234  24848  11097   4996   5340    623   97149
#
#          강원     충북     충남     전북     전남     경북     경남     제주
# 2007  10677  19983  29317  11842  15255  24285  31503   2176
# 2008  13235  10014  21657  12063  10849  15881  24375   4759
# 2009  12312  11537  22860  11634   8984  13316  17119   2115
# 2010   9312   8504  15331  12299  17599  13684  18234   4881
# 2011  12989  18010  46794  16117  15576  16936  39339  13018
# 2012  12156  24773  44450  24288  22222  25713  44760  10256
# 2013  12964  19267  32343  13179  20061  23878  34683   6309
# 2014  12977  16391  35564  13768  17628  41438  49424   8805
# 2015  18868  31125  40311  22552  15631  53046  45325  18690
# 2016  29489  29516  31800  28737  20983  36551  61124  21596
# 2017  29497  30463  25301  17224  20439  25105  38952  14163
# 2018  18983  19833  13228   6991  11760  19429  16746   5426

# %%
modified_permission = year_permission.shift(2)
temp = []
for year in modified_permission.index:
    temp.append(str(year) + '-6-1')
modified_permission.index = pd.to_datetime(temp)

# %%
# 인허가 ,매매가 지수 그래프
plt.figure(figsize=(10,6))
ax = plt.subplot()
ax2 = ax.twinx()

si = '서울'
gu = '서울'

plt.title(si + '-' + gu)
ln1 = ax.plot(price_index[si][gu]['2009-1':], label='매매가')
ln2 = ax2.plot(modified_permission[si]['2009':], label='인허가', color='green',marker="o")
lns = ln1 +ln2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='upper left')
    
plt.show()

# %%
# 미분양

plt.figure(figsize=(10,6))
ax = plt.subplot()
ax2 = ax.twinx()

si = '서울'
gu = '서울'

plt.title(si + '-' + gu)
ln1 = ax.plot(price_index[si][gu]['2009-1':], label='매매가')
ln2 = ax.plot(jun_index[si][gu]['2009-1':], label='전세가')
ln3 = ax2.plot(modified_permission[si]['2009':]/10, label='인허가', color='lightslategray', ls='--')
ln4 = ax2.plot(unsold[si]['2009':], label='미분양', color='y', ls='--')
lns = ln1 +ln2 + ln3 + ln4
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='upper left')
    
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = plt.subplot()
ax2 = ax.twinx()

si = '서울'
gu = '서울'

plt.title(si + '-' + gu)
ln1 = ax.plot(price_index[si][gu]['2009-1':].pct_change(12), label='매매가')
ln2 = ax.plot(jun_index[si][gu]['2009-1':].pct_change(12), label='전세가')
ln3 = ax2.plot(modified_permission[si]['2009':].pct_change(), label='인허가', color='lightslategray', ls='--')
ln4 = ax2.plot(unsold[si]['2009':].pct_change(12), label='미분양', color='y', ls='--')
lns = ln1 +ln2 + ln3 + ln4
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='upper left')
    
plt.show()
# Out:
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/357293039.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ln1 = ax.plot(price_index[si][gu]['2009-1':].pct_change(12), label='매매가')
# /var/folders/j6/q47by8d57xv9mxr1cgqzpp_w0000gn/T/ipykernel_37081/357293039.py:10: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ln2 = ax.plot(jun_index[si][gu]['2009-1':].pct_change(12), label='전세가')

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

def demand(price_index, jeonse_index, index_date, time_range):

    prev_date = index_date - relativedelta(months=time_range)
    prev_date2 = index_date - relativedelta(months=time_range*3)

    demand_df = pd.DataFrame()
    demand_df['매매증감률'] = (price_index.loc[index_date] - price_index.loc[prev_date])/ price_index.loc[prev_date].replace(0,None)
    demand_df['전세증감률'] = (jeonse_index.loc[index_date] - jeonse_index.loc[prev_date])/jeonse_index.loc[prev_date].replace(0,None)
    demand_df['이전최대값'] = price_index[prev_date2:index_date][:-1].max()
    demand_df['최댓값대비증감률'] = (price_index.loc[index_date] - demand_df['이전최대값']) /demand_df['이전최대값'].replace(0,None)

    demand_df['매매가상승'] = demand_df['매매증감률'] > 0.01
    demand_df['전세가상승'] = demand_df['전세증감률'] > 0.01
    demand_df['더빠른전세상승'] = demand_df['전세증감률'] > demand_df['매매증감률']
    demand_df['최댓값대비상승'] = demand_df['최댓값대비증감률'] > 0
    demand_df['수요총합'] = demand_df[['매매가상승','전세가상승','더빠른전세상승','최댓값대비상승']].sum(axis=1)

    demand_df = demand_df[demand_df['수요총합'] == 4]

    seleted_index = []

    for name in demand_df.index:
        if name[0] is not name[1]:
            seleted_index.append((name[0], name[1]))

    demand_df = demand_df.loc[seleted_index]
    
    return demand_df


index_date = datetime(2013, 1, 1)
time_range = 12
demand_1 = demand(price_index, jun_index, index_date, time_range)

# %%
demand_1.head()
# Out:
#            매매증감률     전세증감률      이전최대값  최댓값대비증감률  매매가상승  전세가상승  더빠른전세상승  \
# 부산 영도구  0.010592  0.023187  96.094907   0.00068   True   True     True
#    연제구  0.027149  0.043888  90.282601  0.000141   True   True     True
# 대구 중구    0.03818  0.047353  80.969141   0.00302   True   True     True
#    동구   0.059901  0.083219  76.263379  0.004355   True   True     True
#    서구   0.039148  0.048187  80.862977  0.001546   True   True     True
#
#         최댓값대비상승  수요총합
# 부산 영도구     True     4
#    연제구     True     4
# 대구 중구      True     4
#    동구      True     4
#    서구      True     4

# %%
prev_date = index_date - relativedelta(months=time_range)
prev_date2 = index_date - relativedelta(months=time_range * 3)
graph_start = index_date - relativedelta(months=time_range * 3)

num_row = int((len(demand_1.index)-1)/2)+1

plt.figure(figsize=(15, num_row*5))
for i, spot in enumerate(demand_1.index):
    ax = plt.subplot(num_row, 2, i+1)
    si = spot[0]
    gu = spot[1]
    plt.title(spot)
    ax2 = ax.twinx()
    ln1 = ax.plot(price_index[si][gu][graph_start:], label='매매가')
    ln2 = ax.plot(jun_index[si][gu][graph_start:], label='전세가')
    ln3 = ax2.plot(modified_permission[si][graph_start:]/10,  color='lightslategray', label='인허가')
    ln4 = ax2.plot(unsold[si][graph_start:], color='y', label='미분양')
    ax.axvline(x=index_date, color='lightcoral', linestyle='--')
    ax.axvline(x=prev_date, color='darkseagreen', linestyle='--')
    ax.axvline(x=prev_date2, color='darkseagreen', linestyle='--')
    lns = ln1 +ln2 + ln3 + ln4
    labs = [l.get_label() for l in lns]
    ax.legend(lns, labs, loc='lower right')

plt.show()
